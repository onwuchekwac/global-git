# %%
years= [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
duration= [103, 101, 99, 100, 100, 95, 96, 93, 90]
movie_dict= {year: dur for year, dur in zip(years, duration) }
print(movie_dict)
# Out:
# {2011: 103, 2012: 101, 2013: 99, 2014: 100, 2015: 100, 2016: 95, 2017: 96, 2018: 93, 2019: 90}

# %%
import pandas as pd
durations_df = pd.DataFrame({'duration': movie_dict.values()}, index=movie_dict.keys())
print(durations_df)
# Out:
#       duration
# 2011       103
# 2012       101
# 2013        99
# 2014       100
# 2015       100
# 2016        95
# 2017        96
# 2018        93
# 2019        90

# %%
import matplotlib.pyplot as plt
# plotting
durations_df.plot(kind='line', marker=0)
plt.xlabel('years')
plt.ylabel('durations')
plt.title('Netflix Movie Durations 2011-2020')
plt.show()

# %%
path = r"C:\Users\Admin\Documents\CWW TECH\PERSONAL PROJECT\netflix_data.csv"
netflix_df = pd.read_csv(path)
print(netflix_df.head(5))
# Out:
#   show_id     type                          title director  \
# 0    s981  TV Show                   Bling Empire      NaN
# 1   s2328  TV Show              Gabby's Dollhouse      NaN
# 2   s2673  TV Show  Headspace Guide to Meditation      NaN
# 3   s2754  TV Show         History of Swear Words      NaN
# 4   s3823  TV Show                          Lupin      NaN
#
#                                                 cast        country  \
# 0                                                NaN            NaN
# 1  Laila Lockhart Kraner, Tucker Chandler, Juliet...            NaN
# 2                                    Andy Puddicombe  United States
# 3                                       Nicolas Cage  United States
# 4  Omar Sy, Ludivine Sagnier, Clotilde Hesme, Nic...  United States
#
#   date_added  release_year  duration  \
# 0  15-Jan-21          2021         1
# 1   5-Jan-21          2021         1
# 2   1-Jan-21          2021         1
# 3   5-Jan-21          2021         1
# 4   8-Jan-21          2021         1
#
#                                          description       genre
# 0  Follow LA's wildly wealthy Asian and Asian Ame...  Reality TV
# 1  Cute cats, quirky crafts and colorful magic! J...        Kids
# 2  Headspace takes a friendly, animated look at t...  Docuseries
# 3  Nicolas Cage hosts this proudly profane, funny...  Docuseries
# 4  Inspired by the adventures of Arsène Lupin, ge...    Crime TV

# %%
netflix_df_movies_only = netflix_df.loc[netflix_df['type'].isin(['Movie'])]
netflix_movie_col_subset = netflix_df_movies_only[['title', 'country', 'genre', 'release_year', 'duration']]
print(netflix_movie_col_subset.head(5))
# Out:
#                                                  title        country  \
# 1997                                            Silent  United States
# 2092                                       Sol Levante          Japan
# 2169                                  Cops and Robbers  United States
# 2186                                            Canvas  United States
# 2193  American Factory: A Conversation with the Obamas  United States
#
#               genre  release_year  duration
# 1997       Children          2014         3
# 2092         Action          2020         5
# 2169         Dramas          2020         8
# 2186       Children          2020         9
# 2193  Documentaries          2019        10

# %%
import matplotlib.pyplot as plt
netflix_movie_col_subset.plot.scatter(x='release_year', y='duration')
plt.xlabel('release_year')
plt.ylabel('duration')
plt.title('Movie Duration By Year of Release')
plt.show()

# %%
short_movies = netflix_movie_col_subset.loc[netflix_movie_col_subset['duration'] <60]
print(short_movies.head(20))
# Out:
#                                                   title         country  \
# 1997                                             Silent   United States
# 2092                                        Sol Levante           Japan
# 2169                                   Cops and Robbers   United States
# 2186                                             Canvas   United States
# 2193   American Factory: A Conversation with the Obamas   United States
# 2196  Calico Critters: Everyone's Big Dream Flying i...             NaN
# 2197                  Calico Critters: A Town of Dreams             NaN
# 2200                                               Zion   United States
# 2202                     Cosmos Laundromat: First Cycle     Netherlands
# 2203                     If Anything Happens I Love You   United States
# 2206                        Creating The Queen's Gambit             NaN
# 2207  The Road to El Camino: Behind the Scenes of El...   United States
# 2208                Buddy Thunderstruck: The Maybe Pile   United States
# 2209  Ya no estoy aquí: Una conversación entre Guill...             NaN
# 2210                                              ANIMA  United Kingdom
# 2213                            Sitara: Let Girls Dream        Pakistan
# 2215                  John Was Trying to Contact Aliens   United States
# 2216                             The Claudia Kishi Club   United States
# 2217                                  WHAT DID JACK DO?   United States
# 2218                             Michael Lost and Found          Canada
#
#               genre  release_year  duration
# 1997       Children          2014         3
# 2092         Action          2020         5
# 2169         Dramas          2020         8
# 2186       Children          2020         9
# 2193  Documentaries          2019        10
# 2196       Children          2019        11
# 2197       Children          2017        11
# 2200  Documentaries          2018        12
# 2202         Dramas          2015        12
# 2203         Dramas          2020        13
# 2206  Documentaries          2021        14
# 2207  Documentaries          2019        14
# 2208  Uncategorized          2017        14
# 2209  Documentaries          2020        15
# 2210         Dramas          2019        15
# 2213       Children          2020        16
# 2215  Documentaries          2020        17
# 2216  Documentaries          2020        17
# 2217         Dramas          2020        17
# 2218  Documentaries          2017        19

# %%
color = []
for index, row in netflix_movie_col_subset.iterrows():
    if row['genre'] == 'Children' :
        color.append('red')
    elif row['genre'] == 'Documentary' :
        color.append('blue')
    elif row['genre'] == 'Stand-Up' :
        color.append('green')
    else:
        color.append('black')
print(color[:10])
# Out:
# ['red', 'black', 'black', 'red', 'black', 'red', 'red', 'black', 'black', 'black']

# %%
netflix_movie_col_subset.plot.scatter(x='release_year', y= 'duration', c=color, alpha=0.8)
plt.xlabel('Release_year')
plt.xlabel('Duration(mins')
plt.title('Movie Duration by year of release')
# Out:
# Text(0.5, 1.0, 'Movie Duration by year of release')

# %% [markdown]
# With my analysis, it seems that movies durations declined over the years.
